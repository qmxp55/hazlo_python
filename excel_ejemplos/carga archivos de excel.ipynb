# %%
import pandas as pd

# %%
archivo = '../data/film.xlsx'
cols = ['Year', 'Length', 'Title', 'Subject']
df = pd.read_excel(archivo, usecols=cols)

# %%
df[:20]
# Out:
#     Year  Length                                   Title  Subject
# 0   1990   111.0                 Tie Me Up! Tie Me Down!   Comedy
# 1   1991   113.0                              High Heels   Comedy
# 2   1983   104.0                          Dead Zone, The   Horror
# 3   1979   122.0                                    Cuba   Action
# 4   1978    94.0                          Days of Heaven    Drama
# 5   1983   140.0                               Octopussy   Action
# 6   1984   101.0                            Target Eagle   Action
# 7   1989    99.0  American Angels: Baptism of Blood, The    Drama
# 8   1985   104.0                                  Subway    Drama
# 9   1990   149.0                         Camille Claudel    Drama
# 10  1982   188.0                     Fanny and Alexander    Drama
# 11  1982   117.0             Tragedy of a Ridiculous Man    Drama
# 12  1966   103.0                         A Man & a Woman    Drama
# 13  1986   112.0     A Man & a Woman: Twenty Years Later    Drama
# 14  1966   103.0                   Un Hombre y una Mujer    Drama
# 15  1985   112.0                     Official Story, The    Drama
# 16  1976   150.0          Lindbergh Kidnapping Case, The    Drama
# 17  1929    84.0                               Blackmail  Mystery
# 18  1963   109.0                          Donovan's Reef   Comedy
# 19  1988   110.0             Tucker: The Man & His Dream    Drama

# %%
df.describe()
# Out:
#               Year       Length
# count  1659.000000  1592.000000
# mean   1975.802893   105.179648
# std      17.057848    30.629501
# min    1920.000000     5.000000
# 25%    1967.000000    90.000000
# 50%    1983.000000   102.000000
# 75%    1989.000000   116.000000
# max    1997.000000   450.000000

# %%
df.groupby(['Subject'])['Year'].count()
# Out:
# Subject
# Action             205
# Adventure            4
# Comedy             385
# Crime                1
# Drama              655
# Fantasy              1
# Horror              57
# Music               43
# Mystery            107
# Romance              1
# Science Fiction     38
# Short                1
# War                 34
# Western            119
# Westerns             6
# Name: Year, dtype: int64

# %%
df.groupby(['Subject']).get_group('Action')
# Out:
#       Year  Length                      Title Subject
# 3     1979   122.0                       Cuba  Action
# 5     1983   140.0                  Octopussy  Action
# 6     1984   101.0               Target Eagle  Action
# 21    1981   116.0    Raiders of the Lost Ark  Action
# 23    1991   105.0                 Predator 2  Action
# ...    ...     ...                        ...     ...
# 1618  1992     NaN  El Rublo de las Dos Caras  Action
# 1631  1932   210.0     Hurricane Express, The  Action
# 1646  1992   112.0                        McQ  Action
# 1654  1932   226.0   Shadow of the Eagle, The  Action
# 1655  1989   103.0               Blood & Guns  Action
#
# [205 rows x 4 columns]

# %%
df.groupby(['Subject']).get_group('Action')['Year'].hist()
