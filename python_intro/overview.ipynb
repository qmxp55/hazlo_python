# %% [markdown]
# # Jupyter Notebook overview
#
# ## By Omar Ruiz
# ### @hazlo_python
# #### Esto es Hazlo en Python!
# <!-- ![alt text](logo.png "Title") -->
# <img src="logo.png" width="400">

# %% [markdown]
# Ejemplo de celda con codigo. Aqui estamos cargando las librearias que vamos a necesitar `numpy` y `matplotlib`.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Esto es una ilustracion de como se ve la siguiente integral:
#
# $\displaystyle{\int}_{\pi/2}^{3\pi/2} \sin(x) + \cos(2x)  \, dx$

# %%
f = lambda x: np.sin(x**2) + np.cos(2*x)

x = np.linspace(0, 2*np.pi, 100)
y = f(x)
plt.plot(x,y)

# %%
X = np.linspace(np.pi/2,3*np.pi/2,100)
Y = f(X)
plt.fill_between(X,Y)
plt.plot(x,y)

plt.xticks([np.pi/2,3*np.pi/2], ['$\pi/2$','$3\pi/2$'])
plt.yticks([])
plt.show()
